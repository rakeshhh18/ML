# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('/content/placement-dataset.csv')

# %%
data.head()
# Out:
#           city  cgpa     iq  placement
# 0     New York   6.8  123.0          1
# 1  Los Angeles   5.9  106.0          0
# 2      Chicago   NaN  121.0          0
# 3     New York   7.4  132.0          1
# 4  Los Angeles   5.8  142.0          0

# %%
data.shape
# Out:
# (100, 4)

# %%
data.isnull().sum()
# Out:
# city         0
# cgpa         8
# iq           4
# placement    0
# dtype: int64

# %%
data.describe()
# Out:
#             cgpa          iq   placement
# count  92.000000   96.000000  100.000000
# mean    5.965217  117.916667    0.460000
# std     1.164911   46.913508    0.500908
# min     3.300000    1.000000    0.000000
# 25%     5.000000   90.000000    0.000000
# 50%     6.000000  122.000000    0.000000
# 75%     6.825000  146.750000    1.000000
# max     8.500000  233.000000    1.000000

# %% [markdown]
# #imputation

# %%
fig,ax=plt.subplots(figsize=(9,9))
sns.distplot(data.cgpa)
# Out:
# <ipython-input-14-f9bd8f8b722e>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data.cgpa)
# <Axes: xlabel='cgpa', ylabel='Density'>

# %%
#filling missing values with median value
data['cgpa'].fillna(data['cgpa'].median(),inplace=True)
# Out:
# <ipython-input-15-024fcc932d02>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['cgpa'].fillna(data['cgpa'].median(),inplace=True)

# %%
data.isnull().sum()
# Out:
# city         0
# cgpa         0
# iq           4
# placement    0
# dtype: int64

# %%
data.head()
# Out:
#           city  cgpa     iq  placement
# 0     New York   6.8  123.0          1
# 1  Los Angeles   5.9  106.0          0
# 2      Chicago   6.0  121.0          0
# 3     New York   7.4  132.0          1
# 4  Los Angeles   5.8  142.0          0

# %%
#filling missing values with mean value
data['iq'].fillna(data['iq'].mean(),inplace=True)
# Out:
# <ipython-input-22-edd2b76e1033>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['iq'].fillna(data['iq'].mean(),inplace=True)

# %%
data.isnull().sum()
# Out:
# city         0
# cgpa         0
# iq           0
# placement    0
# dtype: int64

# %%
#filling missing values with mean value
#data['iq'].fillna(data['iq'].mean(),inplace=True)

# %% [markdown]
# #dropping

# %%
dataset=pd.read_csv('/content/placement-dataset.csv')

# %%
dataset.shape
# Out:
# (100, 4)

# %%
dataset.isnull().sum()
# Out:
# city         0
# cgpa         8
# iq           4
# placement    0
# dtype: int64

# %%
dataset=dataset.dropna(how='any')

# %%
dataset.isnull().sum()
# Out:
# city         0
# cgpa         0
# iq           0
# placement    0
# dtype: int64

# %%
dataset.shape
# Out:
# (88, 4)
